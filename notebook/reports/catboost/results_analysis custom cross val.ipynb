# %%
import pickle
import lzma
import pandas as pd

# read the results from the pickle files

results_datetime = "2024_07_27_14_56_55"
model_type = "catboost"
cross_val_type="custom_cross_val"

with lzma.open(f"reports/{model_type}/{cross_val_type}/performances/graphical_scores_{results_datetime}.pkl", "rb") as f:
    graph_perf = pickle.load(f)

num_perf = pd.read_csv(f"reports/{model_type}/{cross_val_type}/performances/numerical_scores_{results_datetime}.csv")

# get the keys of the graph_perf dictionary
temp_values = list(graph_perf.keys())

# %% [markdown]
# # Model hyperparameters

# %%
# load model
with lzma.open(f"reports/{model_type}/{cross_val_type}/models/models_{results_datetime}.pkl", "rb") as f:
    model = pickle.load(f)

model["T_test = 10"].get_params()
# Out:
# {'learning_rate': 0.9928338660390144,
#  'loss_function': 'RMSE',
#  'subsample': 0.6303175971976757,
#  'max_depth': 4,
#  'n_estimators': 113,
#  'colsample_bylevel': 0.8437720854669973,
#  'reg_lambda': 0.23182737383917412}

# %% [markdown]
# # Numerical performances

# %%
num_perf
# Out:
#              MSE      RMSE       MAE        R2      period
# 0   1.168281e-05  0.003418  0.001879  0.940199       train
# 1   2.537972e-08  0.000159  0.000101  0.999954       train
# 2   8.940539e-07  0.000946  0.000464  0.998390       train
# 3   1.602954e-06  0.001266  0.000743  0.997065       train
# 4   6.634159e-07  0.000815  0.000456  0.998674       train
# 5   1.865476e-04  0.013658  0.012430 -0.576726  validation
# 6   3.940380e-05  0.006277  0.005418  0.666954  validation
# 7   5.697263e-04  0.023869  0.021383 -1.597937  validation
# 8   5.660649e-04  0.023792  0.021267 -1.581242  validation
# 9   5.664589e-04  0.023800  0.021310 -1.583038  validation
# 10  6.041188e-04  0.024579  0.021705 -0.322012        test
# 11  5.713545e-04  0.023903  0.021433 -1.605362        test
# 12  4.128173e-05  0.006425  0.005477  0.651081        test
# 13  3.003811e-05  0.005481  0.005186 -0.047844        test
# 14  2.627548e-05  0.005126  0.003552  0.658531        test

# %% [markdown]
# # Graphical performances

# %% [markdown]
# ## training performances

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["training_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Validation scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["validation_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Test scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["testing_scores"].update_layout(width=700, height=600).show(config=config)
