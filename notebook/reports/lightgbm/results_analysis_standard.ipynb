# %%
import pickle
import lzma
import pandas as pd

# read the results from the pickle files

results_datetime = "2024_07_27_14_56_30"
model_type = "lightgbm"
cross_val_type="standard_cross_val"

with lzma.open(f"reports/{model_type}/{cross_val_type}/performances/graphical_scores_{results_datetime}.pkl", "rb") as f:
    graph_perf = pickle.load(f)

num_perf = pd.read_csv(f"reports/{model_type}/{cross_val_type}/performances/numerical_scores_{results_datetime}.csv")

# get the keys of the graph_perf dictionary
temp_values = list(graph_perf.keys())

# %% [markdown]
# # Numerical performances

# %%
num_perf
# Out:
#          MSE      RMSE       MAE        R2      period
# 0   0.000028  0.005311  0.001362  0.932596       train
# 1   0.000024  0.004910  0.001356  0.940865       train
# 2   0.000020  0.004430  0.001121  0.949825       train
# 3   0.000028  0.005279  0.001416  0.931325       train
# 4   0.000035  0.005913  0.001706  0.923717       train
# 5   0.000012  0.003476  0.001178  0.966181  validation
# 6   0.000054  0.007323  0.001912  0.885144  validation
# 7   0.000038  0.006170  0.001692  0.902589  validation
# 8   0.000052  0.007198  0.001719  0.899285  validation
# 9   0.000017  0.004089  0.001480  0.951783  validation
# 10  0.000053  0.007269  0.001853  0.886830        test
# 11  0.000033  0.005720  0.001747  0.916273        test
# 12  0.000056  0.007484  0.001661  0.891142        test
# 13  0.000008  0.002793  0.001162  0.977499        test
# 14  0.000022  0.004673  0.001582  0.938881        test

# %% [markdown]
# # Graphical performances

# %% [markdown]
# ## training performances

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["training_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Validation scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["validation_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Test scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["testing_scores"].update_layout(width=700, height=600).show(config=config)
