# %%
import pickle
import lzma
import pandas as pd

# read the results from the pickle files

results_datetime = "2024_07_27_14_55_05"
model_type = "xgboost"
cross_val_type="standard_cross_val"

with lzma.open(f"reports/{model_type}/{cross_val_type}/performances/graphical_scores_{results_datetime}.pkl", "rb") as f:
    graph_perf = pickle.load(f)

num_perf = pd.read_csv(f"reports/{model_type}/{cross_val_type}/performances/numerical_scores_{results_datetime}.csv")

# get the keys of the graph_perf dictionary
temp_values = list(graph_perf.keys())

# %% [markdown]
# # Numerical performances

# %%
num_perf
# Out:
#          MSE      RMSE       MAE        R2      period
# 0   0.000001  0.001116  0.000706  0.997024       train
# 1   0.000002  0.001311  0.000721  0.995784       train
# 2   0.000002  0.001260  0.000741  0.995942       train
# 3   0.000001  0.001147  0.000707  0.996757       train
# 4   0.000001  0.001130  0.000710  0.997216       train
# 5   0.000003  0.001765  0.000894  0.991276  validation
# 6   0.000005  0.002187  0.001041  0.989759  validation
# 7   0.000009  0.002948  0.001052  0.977766  validation
# 8   0.000006  0.002407  0.001143  0.988737  validation
# 9   0.000004  0.001874  0.000956  0.989875  validation
# 10  0.000003  0.001794  0.000866  0.993104        test
# 11  0.000006  0.002482  0.001069  0.984239        test
# 12  0.000008  0.002815  0.001137  0.984598        test
# 13  0.000006  0.002376  0.001051  0.983725        test
# 14  0.000004  0.002044  0.001055  0.988310        test

# %% [markdown]
# # Graphical performances

# %% [markdown]
# ## training performances

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["training_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Validation scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["validation_scores"].update_layout(width=700, height=600).show(config=config)

# %% [markdown]
# ## Test scores

# %%
for temp in temp_values:
    config = {
        "toImageButtonOptions": {
            "scale": 6,  # Multiply title/legend/axis/canvas sizes by this factor
        }
    }
    graph_perf[temp]["testing_scores"].update_layout(width=700, height=600).show(config=config)
